# %%
from graph.graph import Graph, generate_random_graph
from graph.kruskalMST import kruskalMST
from graph.primMSt import primMST
import time

# %%
ug = Graph(directed=False)
# Out:
# New Undirected Graph created successfully.

# %%
generate_random_graph(ug, 8, 14, 15)
ug.display_adjacency_matrix()
# Out:
# Generated vertices: ['Y', 'I', 'N', 'S', 'X', 'D', 'A', 'R']
# Adding vertex Y to the graph.
# Adding vertex I to the graph.
# Adding vertex N to the graph.
# Adding vertex S to the graph.
# Adding vertex X to the graph.
# Adding vertex D to the graph.
# Adding vertex A to the graph.
# Adding vertex R to the graph.
# Adding undirected edge between S and X with weight 2.
# Adding undirected edge between N and X with weight 14.
# Adding undirected edge between S and R with weight 15.
# Adding undirected edge between Y and X with weight 13.
# Adding undirected edge between N and D with weight 4.
# Adding undirected edge between Y and R with weight 6.
# Adding undirected edge between S and D with weight 4.
# Adding undirected edge between Y and I with weight 6.
# Adding undirected edge between I and R with weight 13.
# Adding undirected edge between X and R with weight 2.
# Adding undirected edge between Y and A with weight 5.
# Adding undirected edge between N and R with weight 14.
# Adding undirected edge between A and R with weight 7.
# Adding undirected edge between Y and D with weight 9.
# Added 14 random edges.
# Adjacency Matrix:
#     Y   I   N   S   X  D  A   R
# Y   0   6   0   0  13  9  5   6
# I   6   0   0   0   0  0  0  13
# N   0   0   0   0  14  4  0  14
# S   0   0   0   0   2  4  0  15
# X  13   0  14   2   0  0  0   2
# D   9   0   4   4   0  0  0   0
# A   5   0   0   0   0  0  0   7
# R   6  13  14  15   2  0  7   0

# %%
ug.plot_graph()

# %%
start = time.time()
mstGraphKruskal = kruskalMST(ug)
mstGraphKruskal.display_adjacency_matrix()
mstGraphKruskal.plot_graph()
end = time.time()
print("Time taken by Kruskal's algorithm: ", end-start)
# Out:
# New Undirected Graph created successfully.
# Adding vertex Y to the graph.
# Adding vertex I to the graph.
# Adding vertex N to the graph.
# Adding vertex S to the graph.
# Adding vertex X to the graph.
# Adding vertex D to the graph.
# Adding vertex A to the graph.
# Adding vertex R to the graph.
# Adding undirected edge between X and S with weight 2.
# Adding undirected edge between R and X with weight 2.
# Adding undirected edge between D and N with weight 4.
# Adding undirected edge between D and S with weight 4.
# Adding undirected edge between A and Y with weight 5.
# Adding undirected edge between R and Y with weight 6.
# Adding undirected edge between I and Y with weight 6.
# Adjacency Matrix:
#    Y  I  N  S  X  D  A  R
# Y  0  6  0  0  0  0  5  6
# I  6  0  0  0  0  0  0  0
# N  0  0  0  0  0  4  0  0
# S  0  0  0  0  2  4  0  0
# X  0  0  0  2  0  0  0  2
# D  0  0  4  4  0  0  0  0
# A  5  0  0  0  0  0  0  0
# R  6  0  0  0  2  0  0  0

# %%
start = time.time()
mstGraphPrim = primMST(ug)
mstGraphPrim.display_adjacency_matrix()
mstGraphPrim.plot_graph()
end = time.time()
print("Time taken by Prim's algorithm: ", end-start)
# Out:
# New Undirected Graph created successfully.
# Adding vertex Y to the graph.
# Adding vertex I to the graph.
# Adding vertex N to the graph.
# Adding vertex S to the graph.
# Adding vertex X to the graph.
# Adding vertex D to the graph.
# Adding vertex A to the graph.
# Adding vertex R to the graph.
# Adding undirected edge between Y and A with weight 5.
# Adding undirected edge between Y and I with weight 6.
# Adding undirected edge between Y and R with weight 6.
# Adding undirected edge between R and X with weight 2.
# Adding undirected edge between X and S with weight 2.
# Adding undirected edge between S and D with weight 4.
# Adding undirected edge between D and N with weight 4.
# Adjacency Matrix:
#    Y  I  N  S  X  D  A  R
# Y  0  6  0  0  0  0  5  6
# I  6  0  0  0  0  0  0  0
# N  0  0  0  0  0  4  0  0
# S  0  0  0  0  2  4  0  0
# X  0  0  0  2  0  0  0  2
# D  0  0  4  4  0  0  0  0
# A  5  0  0  0  0  0  0  0
# R  6  0  0  0  2  0  0  0
