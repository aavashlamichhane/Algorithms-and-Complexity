# %%
from graph.graph import Graph, generate_random_graph
from graph.kruskalMST import kruskalMST
from graph.primMSt import primMST

# %%
dg = Graph(directed=True)
ug = Graph(directed=False)
# Out:
# New Directed Graph created successfully.
# New Undirected Graph created successfully.

# %%
generate_random_graph(ug, 8, 14, 15)
ug.display_adjacency_matrix()
# Out:
# Generated vertices: ['X', 'G', 'N', 'E', 'O', 'I', 'B', 'D']
# Adding vertex X to the graph.
# Adding vertex G to the graph.
# Adding vertex N to the graph.
# Adding vertex E to the graph.
# Adding vertex O to the graph.
# Adding vertex I to the graph.
# Adding vertex B to the graph.
# Adding vertex D to the graph.
# Adding undirected edge between X and G with weight 2.
# Adding undirected edge between X and E with weight 11.
# Adding undirected edge between N and I with weight 15.
# Adding undirected edge between G and I with weight 10.
# Adding undirected edge between G and N with weight 5.
# Adding undirected edge between G and B with weight 1.
# Adding undirected edge between I and D with weight 8.
# Adding undirected edge between N and D with weight 5.
# Adding undirected edge between G and D with weight 7.
# Adding undirected edge between N and O with weight 12.
# Adding undirected edge between E and D with weight 14.
# Adding undirected edge between X and O with weight 6.
# ...

# %%
ug.plot_graph()

# %%
mstGraphKruskal = kruskalMST(ug)
mstGraphKruskal.display_adjacency_matrix()
mstGraphKruskal.plot_graph()
# Out:
# New Undirected Graph created successfully.
# Adding vertex X to the graph.
# Adding vertex G to the graph.
# Adding vertex N to the graph.
# Adding vertex E to the graph.
# Adding vertex O to the graph.
# Adding vertex I to the graph.
# Adding vertex B to the graph.
# Adding vertex D to the graph.
# Adding undirected edge between B and G with weight 1.
# Adding undirected edge between G and X with weight 2.
# Adding undirected edge between D and X with weight 4.
# Adding undirected edge between N and G with weight 5.
# Adding undirected edge between O and X with weight 6.
# Adding undirected edge between D and I with weight 8.
# Adding undirected edge between E and X with weight 11.
# Adjacency Matrix:
#     X  G  N   E  O  I  B  D
# X   0  2  0  11  6  0  0  4
# G   2  0  5   0  0  0  1  0
# N   0  5  0   0  0  0  0  0
# E  11  0  0   0  0  0  0  0
# O   6  0  0   0  0  0  0  0
# I   0  0  0   0  0  0  0  8
# B   0  1  0   0  0  0  0  0
# D   4  0  0   0  0  8  0  0

# %%
mstGraphPrim = primMST(ug)
mstGraphPrim.display_adjacency_matrix()
mstGraphPrim.plot_graph()
# Out:
# New Undirected Graph created successfully.
# Adding vertex X to the graph.
# Adding vertex G to the graph.
# Adding vertex N to the graph.
# Adding vertex E to the graph.
# Adding vertex O to the graph.
# Adding vertex I to the graph.
# Adding vertex B to the graph.
# Adding vertex D to the graph.
# Adding undirected edge between X and G with weight 2.
# Adding undirected edge between G and B with weight 1.
# Adding undirected edge between X and D with weight 4.
# Adding undirected edge between G and N with weight 5.
# Adding undirected edge between X and O with weight 6.
# Adding undirected edge between D and I with weight 8.
# Adding undirected edge between X and E with weight 11.
# Adjacency Matrix:
#     X  G  N   E  O  I  B  D
# X   0  2  0  11  6  0  0  4
# G   2  0  5   0  0  0  1  0
# N   0  5  0   0  0  0  0  0
# E  11  0  0   0  0  0  0  0
# O   6  0  0   0  0  0  0  0
# I   0  0  0   0  0  0  0  8
# B   0  1  0   0  0  0  0  0
# D   4  0  0   0  0  8  0  0
